# %% [markdown]
# <a href="https://colab.research.google.com/github/avaramahmood/Siddhardhan-ML-Course/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
a = pd.Series([1,2,3], index = ['a', 'b', 'c'])
a
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
b = pd.DataFrame({"Hi" : [1,2,3,4], "My Name" : ['hello', 'my', 'name', 'is']})
b
# Out:
#    Hi My Name
# 0   1   hello
# 1   2      my
# 2   3    name
# 3   4      is

# %%
df.loc[2:5]#only rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.iloc[2:5, 3:5]
# Out:
#    petal_width species
# 2          0.2  setosa
# 3          0.2  setosa
# 4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[df['petal_length']<1.4]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 2            4.7          3.2           1.3          0.2  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 22           4.6          3.6           1.0          0.2  setosa
# 35           5.0          3.2           1.2          0.2  setosa
# 36           5.5          3.5           1.3          0.2  setosa
# 38           4.4          3.0           1.3          0.2  setosa
# 40           5.0          3.5           1.3          0.3  setosa
# 41           4.5          2.3           1.3          0.3  setosa
# 42           4.4          3.2           1.3          0.2  setosa

# %%
df.insert(2,'hi',[False]*len(df), allow_duplicates=True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width     hi  petal_length  petal_width species
# 0           5.1          3.5  False           1.4          0.2  setosa
# 1           4.9          3.0  False           1.4          0.2  setosa
# 2           4.7          3.2  False           1.3          0.2  setosa
# 3           4.6          3.1  False           1.5          0.2  setosa
# 4           5.0          3.6  False           1.4          0.2  setosa

# %%
df.drop('hi', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.sort_values(by = 'petal_length')
df.sort_index()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['petal_width'].apply(lambda x: x*2)
# Out:
# 0      0.4
# 1      0.4
# 2      0.4
# 3      0.4
# 4      0.4
#       ...
# 145    4.6
# 146    3.8
# 147    4.0
# 148    4.6
# 149    3.6
# Name: petal_width, Length: 150, dtype: float64

# %%
## .isna()  .notna()
## .fillna(value)
## .dropna()
